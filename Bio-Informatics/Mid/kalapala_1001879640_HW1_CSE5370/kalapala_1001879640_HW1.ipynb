# %% [markdown]
# #Miniconda

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# !which python
# Out:
# conda 4.5.4
# /usr/local/bin/python

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.62.3                |     pyhd3eb1b0_1          79 KB
#     conda-package-handling-1.7.3|   py36h27cfd23_1         946 KB
#     readline-8.1.2             |       h7f8727e_1         423 KB
#     setuptools-58.0.4          |   py36h06a4308_0         979 KB
#     pyopenssl-21.0.0           |     pyhd3eb1b0_1          48 KB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
#     ruamel_yaml-0.15.100       |   py36h27cfd23_0         268 KB
#     tk-8.6.11                  |       h1ccaba5_0         3.2 MB
#     python-3.6.13              |       h12debd9_1        32.5 MB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
# ...

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.6/dist-packages

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - featuretools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.3.3                |   py36h5fab9bb_0         8.3 MB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     certifi-2021.5.30          |   py36h5fab9bb_0         141 KB  conda-forge
#     click-7.1.2                |     pyh9f0ad1d_0          64 KB  conda-forge
# ...

# %% [markdown]
# #Mamba Installation

# %%
! wget -O miniconda.sh https://repo.anaconda.com/miniconda/Miniconda3-py37_4.10.3-Linux-x86_64.sh
# Out:
# --2022-01-31 14:08:46--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.10.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89026327 (85M) [application/x-sh]
# Saving to: ‘miniconda.sh’
#
# miniconda.sh        100%[===================>]  84.90M   177MB/s    in 0.5s
#
# 2022-01-31 14:08:47 (177 MB/s) - ‘miniconda.sh’ saved [89026327/89026327]

# %%
! chmod +x miniconda.sh

# %%
! bash ./miniconda.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package ncurses conflicts for:
# psutil -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.0,<7.0a0|>=6.2,<7.0a0']
# sqlite==3.36.0=hc218d9a_0 -> readline[version='>=8.0,<9.0a0'] -> ncurses[version='>=6.2,<7.0a0|>=6.3,<7.0a0']
# numpy -> python[version='>=3.6,<3.7.0a0'] -> ncurses[version='>=6.0,<7.0a0|>=6.2,<7.0a0']
# ...

# %%
! rm miniconda.sh

# %%
! conda config --add channels conda-forge

# %%
! conda install -y mamba
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     icu-68.2                   |       h9c3ff4c_0        13.1 MB  conda-forge
#     krb5-1.19.2                |       hcc1bbae_3         1.4 MB  conda-forge
# ...

# %%
# !mamba update -qy --all
# Out:
#   Package                    Version  Build                Channel                     Size
# ─────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────
#
#   + importlib-metadata         4.8.1  py36h5fab9bb_0       conda-forge/linux-64       32 KB
#   + libnsl                     2.0.0  h7f98852_0           conda-forge/linux-64       31 KB
#   + libzlib                   1.2.11  h36c2ea0_1013        conda-forge/linux-64       59 KB
#   + typing-extensions          4.0.1  hd8ed1ab_0           conda-forge/noarch          8 KB
#   + zipp                       3.7.0  pyhd8ed1ab_0         conda-forge/noarch         12 KB
#
#   Change:
# ─────────────────────────────────────────────────────────────────────────────────────────────
#
#   - brotlipy                   0.7.0  py36h27cfd23_1003    installed
# ...

# %%
! mamba clean -qafy
# Out:
# Remove all contents from the following package caches?
#   - /usr/local/pkgs
#   - /root/.conda/pkgs

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
# !conda install mamba -n base -c conda-forge
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.

# %%
# !conda config --add channels bioconda

# %%
# !conda config --add channels conda-forge

# %%
# !conda config --show channels
# Out:
# channels:
#   - conda-forge
#   - bioconda
#   - defaults

# %%
# !conda create -n sratool sra-tools
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/sratool
#
#   added / updated specs:
#     - sra-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     curl-7.81.0                |       h2574ce0_0          90 KB  conda-forge
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
# ...

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# sratool                  /usr/local/envs/sratool

# %%
# !conda activate sratool
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# %%bash
# conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# sratool                  /usr/local/envs/sratool

# %%
# !conda install -c bioconda sra-tools
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - sra-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     perl-carp-1.38             | pl5321hdfd78af_4          17 KB  bioconda
#     perl-constant-1.33         | pl5321hdfd78af_2          12 KB  bioconda
#     perl-exporter-5.72         | pl5321hdfd78af_2          16 KB  bioconda
#     perl-parent-0.236          | pl5321hdfd78af_2           8 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:          52 KB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !conda activate sratools
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !conda install -y parallel-fastq-dump
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - parallel-fastq-dump
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     parallel-fastq-dump-0.6.7  |     pyhdfd78af_0          10 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:          10 KB
#
# The following NEW packages will be INSTALLED:
#
#   parallel-fastq-du~ bioconda/noarch::parallel-fastq-dump-0.6.7-pyhdfd78af_0
#
#
#
# ...
# parallel-fastq-dump- | 10 KB     | : 100% 1.0/1 [00:00<00:00,  5.71it/s]
# done
# done
# done

# %%
# !fastq-dump
# Out:
# Usage:
#   /usr/local/bin/fastq-dump.2.11.0 [options] <path> [<path>...]
#   /usr/local/bin/fastq-dump.2.11.0 [options] <accession>
#
# Use option --help for more information
#
# /usr/local/bin/fastq-dump.2.11.0 : 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/MyDrive/
# Out:
#  code.txt
# 'Colab Notebooks'
# 'CS-MS2217_Kalapala 110296254_A.pdf'
# 'Extra Folder'
# 'Fwd: Document from Ravi Teja.eml'
#  HCPractice20.java
# 'Kalapala, Yogesh (Student ID 1001879640).pdf'
# '(no subject).eml'
#  plague_r1.fastq
#  plague_r2.fastq
# 'P Surekha.pdf'
#  Resume_Immature
# 'Screenshot 2020-09-08 at 10.42.51 AM.png'
# 'Screenshot 2020-09-08 at 10.42.53 AM.png'
# 'Screenshot 2020-10-16 at 6.50.08 AM.png'

# %%
# !fastq-dump --help
# !fastq-dump -F --split-files drive/MyDrive/SRR12225014

# %%
# !ls
# Out:
# drive  Miniconda3-4.5.4-Linux-x86_64.sh  sample_data

# %% [markdown]
# #Above code helped to get fastq files

# %% [markdown]
# #Now try megahit

# %%
# !conda install -c bioconda megahit
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - megahit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     megahit-1.2.9              |       h2e03b76_1         2.9 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   megahit            bioconda/linux-64::megahit-1.2.9-h2e03b76_1
#
#
# Proceed ([y]/n)? y
#
#
# ...
# megahit-1.2.9        | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
# done
# done
# done

# %%
# !megahit -1 /content/drive/MyDrive/plague_r1.fastq -2 /content/drive/MyDrive/plague_r2.fastq -o assembly —verbose
# Out:
# 2022-01-31 14:17:40 - MEGAHIT v1.2.9
# 2022-01-31 14:17:40 - Using megahit_core with POPCNT and BMI2 support
# 2022-01-31 14:17:40 - Convert reads to binary library
# 2022-01-31 14:21:57 - b'INFO  sequence/io/sequence_lib.cpp  :   75 - Lib 0 (/content/drive/MyDrive/plague_r1.fastq,/content/drive/MyDrive/plague_r2.fastq): pe, 32235052 reads, 150 max length'
# 2022-01-31 14:21:59 - b'INFO  utils/utils.h                 :  152 - Real: 258.5089\tuser: 47.8962\tsys: 7.5119\tmaxrss: 269080'
# 2022-01-31 14:21:59 - k-max reset to: 141
# 2022-01-31 14:21:59 - Start assembly. Number of CPU threads 2
# 2022-01-31 14:21:59 - k list: 21,29,39,59,79,99,119,141
# 2022-01-31 14:21:59 - Memory used: 12259971072
# 2022-01-31 14:21:59 - Extract solid (k+1)-mers for k = 21
# 2022-01-31 14:50:28 - Build graph for k = 21
# 2022-01-31 14:51:41 - Assemble contigs from SdBG for k = 21
# 2022-01-31 14:55:06 - Local assembly for k = 21
# 2022-01-31 14:58:53 - Extract iterative edges from k = 21 to 29
# ...

# %%
# !conda install -c bioconda prokka
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - prokka
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aragorn-1.2.38             |       h779adbc_4         131 KB  bioconda
#     barrnap-0.9                |       hdfd78af_4         557 KB  bioconda
#     bedtools-2.30.0            |       h7d7f7ad_2        17.9 MB  bioconda
#     blast-2.5.0                |       hc0b0e79_3       137.8 MB  bioconda
# ...

# %% [markdown]
# #Installed Prokka

# %%
# !conda install -c bioconda perl-xml-simple
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.

# %%
# !conda create -n prokka522 perl=5.22 prokka
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/prokka522
#
#   added / updated specs:
#     - perl=5.22
#     - prokka
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blast-2.9.0                |       h20b68b9_1        18.4 MB  bioconda
#     boost-1.68.0               |py37h8619c78_1001         310 KB  conda-forge
#     boost-cpp-1.68.0           |    h11c811c_1000        20.5 MB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     expat-2.2.10               |       h9c3ff4c_0         164 KB  conda-forge
# ...

# %%
# !conda activate prokka
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !mamba create -n prokka-test prokka=1.13 minced=0.3.0 parallel=20180522
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.17.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
# bioconda/linux-64        [] (00m:00s)
# ...

# %%
# !prokka-test final.contigs.fa -o annotations
# Out:
# /bin/bash: prokka-test: command not found

# %%
# %cd assembly/
# Out:
# /content/assembly

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# prokka-test              /usr/local/envs/prokka-test
# prokka522                /usr/local/envs/prokka522
# sratool                  /usr/local/envs/sratool

# %%
# !conda install -c bioconda perl-bioperl
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - perl-bioperl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     atk-1.0-2.36.0             |       h3371d22_4         560 KB  conda-forge
#     cairo-1.16.0               |    ha00ac49_1009         1.5 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
# ...

# %%
# !prokka final.contigs.fa -o annotations
# Out:
# [16:16:47] This is prokka 1.12
# [16:16:47] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [16:16:47] Homepage is https://github.com/tseemann/prokka
# [16:16:47] Local time is Mon Jan 31 16:16:47 2022
# [16:16:47] You are not telling me who you are!
# [16:16:47] Operating system is linux
# [16:16:47] You have BioPerl 1.007002
# [16:16:47] System has 2 cores.
# [16:16:47] Option --cpu asked for 8 cores, but system only has 2
# [16:16:47] Will use maximum of 2 cores.
# [16:16:47] Annotating as >>> Bacteria <<<
# [16:16:47] Generating locus_tag from 'final.contigs.fa' contents.
# [16:16:47] Setting --locustag MOIAEOBL from MD5 682ae8b568ace8dce9346f24fc36e5f3
# [16:16:47] Creating new output folder: annotations
# [16:16:47] Running: mkdir -p annotations
# [16:16:47] Using filename prefix: PROKKA_01312022.XXX
# [16:16:47] Setting HMMER_NCPU=1
# [16:16:47] Writing log to: annotations/PROKKA_01312022.log
# [16:16:47] Command: /usr/local/bin/prokka final.contigs.fa -o annotations
# ...

# %%
# !ls
# Out:
# checkpoints.txt  final.contigs.fa      log
# done		 intermediate_contigs  options.json

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !zip -r /content/file.zip /content/assembly/annotations/
# Out:
#   adding: content/assembly/annotations/ (stored 0%)
#   adding: content/assembly/annotations/PROKKA_01312022.log (deflated 80%)
#   adding: content/assembly/annotations/PROKKA_01312022.txt (deflated 9%)
#   adding: content/assembly/annotations/PROKKA_01312022.err (deflated 90%)
#   adding: content/assembly/annotations/PROKKA_01312022.tbl (deflated 84%)
#   adding: content/assembly/annotations/PROKKA_01312022.fna (deflated 69%)
#   adding: content/assembly/annotations/PROKKA_01312022.tsv (deflated 77%)
#   adding: content/assembly/annotations/PROKKA_01312022.sqn (deflated 82%)
#   adding: content/assembly/annotations/PROKKA_01312022.ffn (deflated 69%)
#   adding: content/assembly/annotations/PROKKA_01312022.gff (deflated 72%)
#   adding: content/assembly/annotations/PROKKA_01312022.fsa (deflated 70%)
#   adding: content/assembly/annotations/PROKKA_01312022.gbk (deflated 69%)
#   adding: content/assembly/annotations/PROKKA_01312022.faa (deflated 44%)

# %%
from google.colab import files
files.download("/content/file.zip")

# %%
# !zip -r /content/file.zip /content/assembly/

# %%
# !wget https://anaconda.org/bioconda/glimmer/3.02/download/linux-64/glimmer-3.02-3.tar.bz2

# %%
# !tar -xvjf glimmer-3.02-3.tar.bz2
# Out:
# info/hash_input.json
# info/index.json
# info/files
# info/about.json
# info/paths.json
# info/LICENSE.txt
# info/git
# info/test/run_test.sh
# info/recipe/build.sh
# info/recipe/meta.yaml.template
# bin/get-motif-counts.awk
# info/recipe/meta.yaml
# bin/match-list-col.awk
# bin/not-acgt.awk
# bin/upstream-coords.awk
# bin/g3-from-scratch.csh
# bin/g3-from-training.csh
# bin/glim-diff.awk
# info/recipe/conda_build_config.yaml
# bin/g3-iterated.csh
# bin/test
# bin/window-acgt
# bin/uncovered
# bin/entropy-profile
# bin/extract
# bin/entropy-score
# bin/anomaly
# bin/start-codon-distrib
# bin/multi-extract
# bin/score-fixed
# bin/build-icm
# bin/build-fixed
# bin/long-orfs
# bin/glimmer3

# %%
# !./bin/glimmer3
# Out:
# Starting at Mon Jan 31 17:15:27 2022
#
# USAGE:  glimmer3 [options] <sequence-file> <icm-file> <tag>
#
# Read DNA sequences in <sequence-file> and predict genes
# in them using the Interpolated Context Model in <icm-file>.
# Output details go to file <tag>.detail and predictions go to
# file <tag>.predict
#
# Options:
#  -A <codon-list>
#  --start_codons <codon-list>
#     Use comma-separated list of codons as start codons
#     Sample format:  -A atg,gtg
#     Use -P option to specify relative proportions of use.
#     If -P not used, then proportions will be equal
#  -b <filename>
#  --rbs_pwm <filename>
#     Read a position weight matrix (PWM) from <filename> to identify
#     the ribosome binding site to help choose start sites
#  -C <p>
#  --gc_percent <p>
#     Use <p> as GC percentage of independent model
#     Note:  <p> should be a percentage, e.g., -C 45.2
#  -E <filename>
#  --entropy <filename>
#     Read entropy profiles from <filename>.  Format is one header
# ...

# %%
# !./bin/glimmer3 final.contigs.fa -o annotations
# Out:
# Starting at Mon Jan 31 18:17:26 2022
#
# ERROR:  Bad max overlap bases (-o option)
#   value = "annotations"USAGE:  glimmer3 [options] <sequence-file> <icm-file> <tag>
#
# Read DNA sequences in <sequence-file> and predict genes
# in them using the Interpolated Context Model in <icm-file>.
# Output details go to file <tag>.detail and predictions go to
# file <tag>.predict
#
# Options:
#  -A <codon-list>
#  --start_codons <codon-list>
#     Use comma-separated list of codons as start codons
#     Sample format:  -A atg,gtg
#     Use -P option to specify relative proportions of use.
#     If -P not used, then proportions will be equal
#  -b <filename>
#  --rbs_pwm <filename>
#     Read a position weight matrix (PWM) from <filename> to identify
#     the ribosome binding site to help choose start sites
#  -C <p>
#  --gc_percent <p>
#     Use <p> as GC percentage of independent model
#     Note:  <p> should be a percentage, e.g., -C 45.2
#  -E <filename>
#  --entropy <filename>
# ...
